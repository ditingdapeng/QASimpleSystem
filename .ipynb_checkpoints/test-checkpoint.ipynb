# %%
import json
def read_corpus():
    """
    读取给定的语料库，并把问题列表和答案列表分别写入到 qlist, alist 里面。 在此过程中，不用对字符换做任何的处理（这部分需要在 Part 2.3里处理）
    qlist = ["问题1"， “问题2”， “问题3” ....]
    alist = ["答案1", "答案2", "答案3" ....]
    务必要让每一个问题和答案对应起来（下标位置一致）
    """
    # TODO 需要完成的代码部分 ...
    qlist = []
    alist = []
    filename = 'train-v2.0.json'
    datas = json.load(open(filename,'r'))
    data = datas['data']
    for d in data:
        paragraph = d['paragraphs']
        for p in paragraph:
            qas = p['qas']
            for qa in qas:
                #print(qa)
                #处理is_impossible为True时answers空
                if(not qa['is_impossible']):
                    qlist.append(qa['question'])
                    alist.append(qa['answers'][0]['text'])
    assert len(qlist) == len(alist)  # 确保长度一样
    return qlist, alist
qlist,alist = read_corpus()

# %%
'famous?'
# Out:
# 'famous?'

# %%
import nltk
from nltk.corpus import stopwords
import codecs
import re
import numpy as np

def lowerCase(ori_list):
    return [q.lower() for q in ori_list]
def tokenizer(ori_list):
    #分词时处理标点符号
    SYMBOLS = re.compile('[\s;\"\",.!?\\/\[\]\{\}\(\)-]+')
    new_list = []
    for q in ori_list:
        words = SYMBOLS.split(q.strip())
        new_list.append(' '.join(words))
    return new_list

# nltk中stopwords包含what等，但是在QA问题中，这算关键词，所以不看作关键词    
def removeStopWord(ori_list):
    new_list = []
    restored = ['what','when','which','how','who','where']
    english_stop_words = list(set(stopwords.words('english')))#['what','when','which','how','who','where','a','an','the'] #
    for w in restored:
        english_stop_words.remove(w)
    for q in ori_list:
        sentence = ' '.join([w for w in q.strip().split(' ') if w not in english_stop_words])
        new_list.append(sentence)
    return new_list

def removeLowFrequence(ori_list,vocabulary,thres = 10):
    #根据thres筛选词表，小于thres的词去掉
    new_list = []
    for q in ori_list:
        sentence = ' '.join([w for w in q.strip().split(' ') if vocabulary[w] >= thres])
        new_list.append(sentence)
    return new_list

def replaceDigits(ori_list,replace = '#number'):
    #将数字统一替换为replace,默认#number
    DIGITS = re.compile('\d+')
    new_list = []
    for q in ori_list:
        q = DIGITS.sub(replace,q)
        new_list.append(q)
    return new_list

# 定义处理一个单词的函数: 使用参数来控制是否变换小写及停用词去除；接受的是数组list
def handle_sentence(word_list, isLowCase=True, isStopWord=True, isReplaceDigits=True):
    if isLowCase:
        word_list = lowerCase(word_list)
    word_list = tokenizer(word_list)
    if isStopWord:
        word_list = removeStopWord(word_list)
    if isReplaceDigits:
        word_list = replaceDigits(word_list)
    return word_list

new_qlist = handle_sentence(qlist)

# %%
# 此时的new_qlist已经是去掉符号和停用词的了；
new_qlist
# Out:
# ['when beyonce start becoming popular',
#  'what areas beyonce compete when growing',
#  "when beyonce leave destiny's child become solo singer",
#  'what city state beyonce grow',
#  'which decade beyonce become famous',
#  'what r&b group lead singer',
#  'what album made worldwide known artist',
#  "who managed destiny's child group",
#  'when beyoncé rise fame',
#  "what role beyoncé destiny's child",
#  'what first album beyoncé released solo artist',
#  'when beyoncé release dangerously love',
#  'how many grammy awards beyoncé win first solo album',
#  "what beyoncé's role destiny's child",
#  "what name beyoncé's first solo album",
#  'second solo album what entertainment venture beyonce explore',
#  'which artist beyonce marry',
#  'set record grammys how many beyonce win',
#  'what movie beyonce receive first golden globe nomination',
#  'when beyonce take hiatus career take control management',
#  'which album darker tone previous work',
#  'what movie portraying etta james beyonce create sasha fierce',
#  "when destiny's child end group act",
#  "what name beyoncé's second solo album",
#  "what beyoncé's first acting job #number",
#  'who beyoncé married',
#  "what name beyoncé's alter ego",
#  'music what recurring elements',
#  'time magazine named one #number what people century',
#  'which magazine declared dominant woman musician',
#  'which decade recording industry association america recognize beyonce top certified artist',
#  'what magazine rated beyonce powerful female musician #number',
#  'how beyonce describe feminist',
#  'which years time rate beyonce #number influential people world',
#  'how many records beyonce sold #number year career',
#  "how many records beyoncé sell part destiny's child",
#  "leaving destiny's child how many records beyoncé release name",
#  'how many grammy awards beyoncé',
#  'what magazine named beyoncé powerful female musician #number',
#  "beyonce's younger sibling also sang what band",
#  'where beyonce get name',
#  "what race beyonce's father",
#  "beyonce's childhood home believed what religion",
#  "beyonce's father worked sales manager what company",
#  "beyonce's mother worked what industry",
#  "what younger sister beyonce also appeared destiny's child",
#  'beyonce descendent what arcadian leader',
#  "what company beyoncé's father work when child",
#  "what beyoncé's mother when beyoncé child",
#  "what name beyoncé's younger sister",
#  'beyoncé descendant which acadian leader',
#  'beyoncé raised what religion',
#  'what town beyonce go school',
#  "who first person notice beyonce's singing ability",
#  'beyonce moved which town left first elementary school',
#  "which teachers discovered beyonce's musical talent",
#  'which church beyonce member soloist choir',
#  'what type school parker elementary school',
#  'which song beyonce sing win competition age #number',
#  "what city beyoncé's elementary school located",
#  "what name beyoncé's first dance instructor",
#  'how old beyoncé when school talent show',
#  'what choir beyoncé sing two years',
#  "who decided place beyonce's group star search talent show",
#  '#number who decided manage girls singing group',
#  'who first record label give girls record deal',
#  'who brought beyonce california enter group star search',
#  "what year beyonce's father quit job manage group",
#  "what large record company recorded beyonce's group's first album",
#  "what record company first signed beyonce's group later cut",
#  'what age beyonce meet latavia robertson',
#  'how old beyoncé when met latavia roberson',
#  'what name first group beyoncé part',
#  "who placed girl's tyme star search",
#  'when beyoncé begin manage girl group',
#  'who signed girl group october #number #number',
#  "which film featured destiny's child's first major single",
#  "which song destiny's child take home grammy award best r&b performance",
#  'who beyonce record movie best man',
#  "beyonce's group changed name destiny's child what year",
#  "name destiny's child based quote which book bible",
#  "debut song killing time featured what movie's sound track",
#  'what song best r&b performance #number annual grammy awards',
#  "what singer beyonce record song movie ''the best man",
#  "where destiny's child get name",
#  "destiny's child song killing time included which film's soundtrack",
#  "what destiny's child's first major song hit",
#  "when destiny's child release second album",
#  'who beyoncé sing duet best man film',
#  'what mental health issue beyonce go',
#  'what event occured publicly criticized',
#  'who supported beyonce depression',
#  "what event caused beyonce's depression",
#  'how long beyonce depressed',
#  'who helped beyonce fight depression',
#  "who replaced luckett roberson destiny's child",
#  "who blamed luckett roberson leaving destiny's child",
#  "who helped beyoncé overcome depression years following destiny's child split",
#  "which newest member removed destiny's child",
#  "charlie's angels featured which single band members",
#  'how many weeks single independent women part stay top',
#  'what network beyonce land major movie role',
#  'third album survivor sold how many first week',
#  "what french composer wrote original opera ''carmen'' #numberth century",
#  'what album caused lawsuit filed #number',
#  "independent women part which #number film's soundtrack",
#  'which film beyoncé star #number mekhi phifer',
#  "what name destiny child's third album",
#  'who filed lawsuit survivor',
#  "when destiny's child announce hiatus",
#  'who beyonce star movie austin powers goldmember',
#  "which three countries beyonce's song work achieve top ten status",
#  'beyonce starred cuba gooding jr which film',
#  'who beyonce record lead single movie fighting temptations',
#  'which song soundtrack better charts',
#  'what film beyonce appear mike myers',
#  'what large amount movie goldmember gross',
#  'what genre movie beyonce star cuba gooding jr',
#  "what song lead single film's sound track",
#  "how critics view movie ''the fighting temptations''",
#  'what film beyoncé star mike myers #number',
#  "what beyoncé's character called austin powers goldmember",
#  "which song beyoncé release lead single austin powers goldmember's soundtrack",
#  'what musical comedy beyoncé star along cuba gooding jr #number',
#  'what song beyoncé release lead single fighting tempations',
#  "what highest beyonce's first solo recording achieved billboard hot #number",
#  "beyonce's first album called what",
#  'how many dangerously love sould worldwide since debut',
#  "beyonce's first number one song which song",
#  'how many top five singles came first album',
#  "beyonce's first solo album u what artist lead single",
#  'what solo album beyonce release #number',
#  'album dangerously love achieved what spot billboard top #number chart',
#  'closer get recorded which artist',
#  "which artist associated beyoncé's premiere solo recording",
#  'when beyoncé release first solo album',
#  "what lead single beyoncé's first album",
#  'who helped beyoncé earn grammy award best r&b performance duo group #numberth annual grammy awards',
#  "how many awards beyoncé win #numberth grammy's awards",
#  "destiny's child's final album named what",
#  "destiny's child got star hollywood walk fame what year",
#  'what year beyonce embark dangerously love tour europe',
#  "what name final album destiny's child",
#  "announced destiny's child would disban what european city",
#  "when destiny's child get star hollywood walk fame",
#  "what name beyoncé's european start started november #number",
#  'who beyoncé tour verizon lades first tour',
#  'what major event beyoncé perform february #number #number',
#  "what name final studio album destiny's child",
#  'how many albums beyonce sell first week when released second album',
#  'lead single album which song',
#  'how many countries song irreplaceable get number one status',
#  'how many singles second album produce',
#  "what birthday beyonce's album b'day celebrate",
#  "what artist beyonce duet single deja vu''",
#  "how high ''deja vu'' climb billboard chart",
#  "what name beyoncé's second album",
#  "how many copies b'day sell first week release",
#  'who collaborated beyoncé single deja vu',
#  "which single b'day released u k",
#  'what movie beyonce act #number',
#  'second movie beyonce what film',
#  'single listen featured which movie',
#  "beyonce's first world tour when",
#  "how much money beyonce's tour make #number",
#  "how many millions dollars ''the pink panther'' gross world wide",
#  'what beyonce call first concert tour',
#  "who beyonce's duet ''beautiful liar''",
#  'which film beyoncé star steve martin',
#  "beyoncé's role dreamgirls based what pop singer",
#  'what lead single dreamgirls soundtrack',
#  "what name beyoncé's first international tour",
#  'what pop singer duet beyoncé beautiful liar',
#  'beyonce got married #number',
#  'third album sasha fierce released when',
#  'which decade beyonce top ten songs woman',
#  'which singer beat beyonce best video performance',
#  '#number beyonce started second world tour grossed how much money',
#  'how reveal marriage',
#  'when beyonce begin second world tour',
#  'who beat beyonce best female video',
#  'how much second world tour make dollars',
#  'when beyoncé get married',
#  'who beyoncé marry',
#  "who beyoncé's alter ego",
#  'video what song beyoncé #number mtv video year award',
#  'which prominent star felt #number female video year award went beyoncé instead taylor swift',
#  'beyonce portrayed which character film cadillac records',
#  'beyonce gave entire salary cadillac records which organization',
#  "which song beyonce sing first couple's inaugural ball",
#  'what genre film movie obsessed which beyonce starred',
#  'fight scene movie obsessed which award beyonce',
#  'where beyonce donate salary movie cadillac records',
#  'what thriller film beyonce star',
#  'what name woman played obsessed',
#  'how much buget film gross',
#  'which singer beyoncé portray cadillac records',
#  "which organization received beyoncé's entire cadillac records salary",
#  'where beyoncé perform january #number #number',
#  'which thriller film beyoncé star ali larter',
#  'how many awards beyonce nominated #numbernd grammy awards',
#  'beyonce tied which artist nominations female artist',
#  '#number beyonce worked which famous singer',
#  'how many number one singles beyonce song telephone',
#  'beyonce tied who number one singles female',
#  'beyonce received how many nominations #numbernd annual grammy awards',
#  'what song sixth first place song beyonce',
#  'who else appeared beyonce telephone',
#  'who tie six top songs',
#  'who beyonce tie nominations year',
#  'how many nominations beyoncé receive #numbernd grammy awards ceremony',
#  'who beyoncé tie grammy nominations female artists',
#  "beyoncé featured artist which singer's hit telephone",
#  'who beyoncé lady gaga tie number one hits since #number',
#  'beyonce would take break music which year',
#  'which year beyonce father part business ways',
#  'which famous landmark beyonce see china',
#  'what year beyonce hiatus',
#  'who inspired hiatus',
#  'when stop using father manager',
#  'how long hiatus last',
#  'what beyoncé announce january #number',
#  'who suggested hiatus beyoncé',
#  'who beyoncé part ways hiatus',
#  'how long hiatus last',
#  'which year reports beyonce performing muammar gaddafi surface',
#  'who beyonce donate money earned shows',
#  'beyonce became first female artist perform solo #number years which stage',
#  "which organization beyonce's spokespeople confirm donations",
#  'beyonce listed #number highest paid performer per what',
#  'hoe everyone learn beyonce performed kaddafi',
#  'when leak happen',
#  'who tell donation',
#  'where beyonce perform #number',
#  'who beyoncé perform privately #number',
#  "who released information beyoncé's performance libyan ruler",
#  'which organization beyoncé donate pay private performance',
#  'beyoncé first female singer headline what #number glastonbury festival',
#  "beyonce's fourth album debuted what year",
#  'which single success album',
#  'beyonce award which activity #number',
#  '#number beyonce performed four nights where',
#  "when beyonce's forth album released",
#  'how many copies album sell first week',
#  'who awarded beyonce award writing',
#  'when perform roseland ballroom',
#  "what name beyoncé's fourth studio album",
#  'when #number released',
#  'how many copies #number sold first week',
#  'what magazine beyoncé write story earlier hiatus',
#  'where beyoncé perform four nights standing room concerts #number',
#  'when beyonce first child',
#  'where beyonce give birth first child',
#  "beyonce's first child named what",
#  'first appearance performing since giving birth where',
#  'when beyonce first child',
#  "what child's name",
#  'how long birth child performed',
#  'how many nights perform atlantic city',
#  'when beyoncé give birth daughter',
#  'what beyoncé name daughter',
#  'where blue ivy born',
#  "where beyoncé's first public performance giving birth",
#  'how many nights beyoncé play resort',
#  "destiny's child released compilation album which topic",
#  "beyonce's documentary movie called what",
#  'what beyonce sign #number',
#  "when destiny's child release album love songs",
#  'what title added track love songs',
#  'whose inauguration perform national anthem',
#  'how many tweets per minute half time show get',
#  "when destiny's child release love songs",
#  'what new track love songs',
#  "what beyoncé sing president obama's second inauguration",
#  "what event beyoncé perform one month obama's inauguration",
#  "what name beyoncé's documentary film",
#  "how many dates beyonce's mrs carter show entail",
#  "one beyonce's successful tours yet which one",
#  'beyonce wrote which song movie epic',
#  'beyonce voiced character which animated film',
#  'when tour begin',
#  'what event beyonce honorary chair',
#  'what part voice movie epic',
#  'what song beyonce record film epic',
#  "what name beyoncé's tour started april #number",
#  'how many dates mrs carter show world tour',
#  'which amy winehouse song beyoncé cover release may #number',
#  'beyoncé honorary chair #number what',
#  'which character film epic voiced beyoncé',
#  'where beyonce release #numberth album huge surprise',
#  'when beyonce get fifth consecutive number one hit album',
#  'where album released',
#  'who joined beyonce run tour',
#  'who reported beyonce e top earning woman music',
#  'how much earnings year',
#  'when beyoncé release fifth studio album',
#  'how many digital copies fifth album beyoncé sell six days',
#  "what song beyoncé's fifth studio album featured husband",
#  'what name tour featuring beyoncé jay z',
#  'how many awards beyonce take home #numberth grammy awards',
#  'which artist beat beyonce album year',
#  'which magazine beyonce pose cover august #number',
#  'beyonce would perform who superbowl #number',
#  'beyonce took home how many awards #numberth grammy awards',
#  'beyonce lost which artist album year',
#  'who beyonce perform next superbowl #number',
#  'beyonce three grammies #number how many nominated',
#  'what magazine cover model',
#  'who would perform superbowl #number',
#  'what british band beyonce perform album',
#  'how many awards beyoncé nominated #numberth annual grammys',
#  'how many awards beyoncé win #numberth annual grammys',
#  'beyoncé lost album year award which entertainer',
#  'which magazine beyoncé pose cover making first black female artist',
#  'who beyonce perform super bowl #number',
#  'beyonce released song formation which online music service',
#  "beyonce's new single released super bowl called what",
#  'what day beyonce release single formation',
#  'how single released',
#  'what name streaming service',
#  'what kind platform song released',
#  'when beyoncé release formation',
#  'where beyoncé exclusively release single formation',
#  'april #number how many albums jay z beyonce sold together',
#  'where beyonce become pregnant',
#  'beyonce described what hardest thing endure',
#  'who beyonce relationship',
#  'when beyonce jay z married',
#  'together how records sold',
#  'how beyonce deal miscarriage child',
#  'where beyonce when became pregnant',
#  "which music video beyoncé star jay z's girlfriend creating speculation relationship",
#  'when beyoncé jay z married',
#  'how many records combined beyoncé jay z sold',
#  'what beyoncé describe saddest thing life',
#  'where beyoncé get pregnant',
#  'jay z beyonce attended which event together august #number',
#  'beyonce confirmed what performing one songs',
#  'how many people watched #number mtv music awards',
#  'where announce pregnancy',
#  'broadcast watched history',
#  'what even recorded guinness world records',
#  'what searched term week aug #number #number',
#  'what song perform mtv awards',
#  'where beyoncé announce pregnancy',
#  'what song beyoncé sing prior announcing pregnancy',
#  'how many people watched #number mtv video music awards',
#  'what searched term google week august #number #number',
#  'jay z website called what',
#  'which song jay z talked pregnancy struggles',
#  "what name beyonce's daughter",
#  'what hospital baby delivered',
#  'what named song dedicated child',
#  'what b c stand',
#  'who credited cries song',
#  'when beyoncé give birth daughter',
#  'what beyoncé jay z name daughter',
#  'what song jay z release two days blue ivy born',
#  'what included end glory',
#  'how blue ivy credited glory',
#  'beyonce jay z went rally acquittal',
#  'beyonce sang which song #number presidential inauguration',
#  'how much beyonce raise obama #number #number club',
#  'what endorse march #number #number',
#  'what attend july #number',
#  'what sing #number presidential inauguration',
#  'what song beyoncé perform #number inauguration obama',
#  'what song beyoncé perform first inaugural dance obamas',
#  'what social media platform beyoncé upload picture paper ballot',
#  'when beyoncé endorse march #number #number',
#  'beyonce interview which magazine asked feminism',
#  'beyonce supported which campaign encourages leadership girls',
#  'where beyonce quoted saying modern day feminist',
#  'when say feminist',
#  'what campaign contribute',
#  'what song release #number response speech',
#  'what ban bossy encourage',
#  'beyoncé used words which nigerian author song flawless',
#  'which campaign beyoncé contribute encourages leadership females',
#  'beyonce signed letter who #number',
#  'important un summit took place when',
#  'letter beyonce signed focused what issue',
#  'what set developing funding',
#  'when beyonce sign letter one campaign',
#  'letter addressed',
#  'who women',
#  'when meet',
#  'who beyoncé sign letter #number',
#  'who letter addressed',
#  'what angela merkel serving relation letter',
#  'what letter want two recipients focus',
#  "beyonce along jay z met whom's family death",
#  'beyonce jay z gave lots money bail who prison',
#  "who's death caused protest",
#  'how much bail money spend',
#  'beyonce beat which musical artists paid june #number june #number',
#  'beyonce jay z got guinness world record what #number',
#  'beyonce became highest paid black musician which year',
#  "may #number how much beyonce's total worth",
#  '#number #number which entertainers beyonce beat earnings',
#  '#number who placed beyonce #number celebrity list',
#  'when jay z become highest paid black celebrity couple',
#  'how much earn #number',
#  "what beyonce's net worth #number",
#  "who began reporting beyoncé's annual earnings starting #number",
#  'when beyoncé become highest paid black musician ever',
#  'who predicted beyoncé would become highest paid black entertainer',
#  'when jay z beyoncé become first music couple worth billion dollars',
#  "beyonce's range singing how many octaves",
#  "who talked beyonce's tone timbre distinctive",
#  "which critic called beyonce's voice versatile",
#  "which era credited influenced beyonce's singing style jody rosen",
#  'how many octaves beyonce',
#  "what daily mail say beyonce's voice",
#  "what rosen claim influenced beyonce's style",
#  'what critics claim',
#  "how many octaves beyoncé's voice span",
#  "beyoncé known centerpiece destiny's child",
#  "new york times' jon pareles calls beyoncé's voice velvety yet what",
#  "what jody rosen say influenced beyoncé's vocal style",
#  'music beyonce generally categorized what genre',
#  'besides r&b which genres beyonce dabble',
#  'beyonce mostly releases english songs what language release songs',
#  'spanish songs beyonce released what',
#  'beyonce coached spanish songs which american',
#  'what kind music beyonce',
#  'what language mainly sing',
#  'what language sung',
#  'what album release spanish',
#  'what style music beyoncé usually perform',
#  'what language beyoncé release several songs',
#  'who coached beyoncé spanish recordings',
#  'what album spanish songs come',
#  'beyonce create which aspect music',
#  'example song aimed towards male audience what',
#  "what theme beyonce's early music",
#  'jay z what new themes',
#  'what get credits music',
#  'what part production',
#  "beyoncé's early recordings empowered who",
#  'addition co writing credits beyoncé also got what credits albums',
#  'rather beats what two things beyoncé usually come producers',
#  'pop songwriter year award #number awarded',
#  'beyonce received pop songwriter year award which event',
#  'beyonce number writing credits number one singles',
#  'beyonce joined #number women what list billboard magazine #number',
#  'when beyonce become first african american woman win pop songwriter year',
#  'what place tied songwriting credits',
#  'who listed number #number list top #number hot #number songwriters',
#  'where place writing credits three number one songs',
#  'what beyoncé win #number making first black woman',
#  'who gave beyoncé pop songwriter year award #number',
#  "beyoncé one how many women billboard magazine's #number top #number hot #number songwriters list",
#  'what number beyoncé top #number hot #number songwriters list',
#  'beyonce credit major influence music',
#  'how old beyonce when went first michael jackson concert kid',
#  'beyonce gave tribute award who #number',
#  'beyonce cites mariah carey making want start what',
#  'who influenced beyonce',
#  'what song mariah carey influenced',
#  "who beyoncé's biggest musical influence",
#  "what beyoncé's first concert",
#  'who beyoncé feel around entertainer',
#  'who credit inspiration get what',
#  'what song caused beyoncé practice runs child',
#  'what themes influenced acting role dreamgirls',
#  'which singer beyonce honor entertaining song deja vu',
#  'who motivated beyonce explore areas music',
#  'what movie influenced beyonce towards empowerment themes',
#  'how etta james influence',
#  "where perform wearing baker's hula skirt",
#  "what singer inspired beyoncé's b'day album",
#  'what song beyoncé sing #number concert honor josephine baker',
#  'beyonce noted which first lady saying proves',
#  'which month year beyonce credit madonna inspiring take control career',
#  'beyonce said who embodies definition inspiration strong woman',
#  'who personally influences beyonce',
#  'hoe describe oprah winfrey',
#  'how describe jean michel basquiat',
#  'how madonna influence',
#  'how describe jay z',
#  'who inspires beyoncé',
#  'who beyoncé describe definition inspiration',
#  'who beyoncé describe lyrical raw',
#  'who inspired beyoncé take control career',
#  'beyonce female tour band whose name what',
#  'beyonce singers background known name',
#  'mamas members included which #number musicians',
#  'mamas first appearance when',
#  'what band beyonce introduce #number',
#  "what song name band suga mama song b'day album share",
#  'where suga mama band make first appearance',
#  'what band supports beyonce tours',
#  "what name beyoncé's female tour band",
#  'suga mama also song which beyoncé album',
#  "what beyoncé's backup singers called",
#  'when mamas make debut',
#  'what characteristics beyonce received acclaim',
#  'which former president def jam called beyonce greatest entertainer alive',
#  'what beyonce receive praise',
#  'who chose number one list best singers dancers',
#  'how l reid described',
#  'how alice jones describe',
#  'who beyoncé number one five best singer dancers',
#  'who said beyoncé best entertainer alive',
#  'beyonce self proclaimed alter ego named what',
#  'alter ego born when according beyonce',
#  'what year beyonce away sasha fierce',
#  'beyonce brought back sasha fierce which event',
#  'how describe sasha',
#  'later what say sasha',
#  "what name beyoncé's alter ego",
#  'when beyoncé introduce sasha fierce',
#  'sasha fierce created making what song',
#  'who beyoncé tell february #number sasha fierce longer needed',
#  "beyonce's sex appeal characterized what",
#  'which music journalist described beyonce crossover sex symbol',
#  'which word spawned term used describe beyonce #number',
#  'bootylicious song which act beyonce performed',
#  'oxford dictionary added which word #numbers dedicated beyonce',
#  'what word often used describe beyonce',
#  'when term added dictionary',
#  'what journalist wrote beyoncé sex symbol',
#  "beyoncé's physical shape what slang term used describe",
#  "what year slang term title destiny's child song also used describe beyoncé put dictionary",
#  'how beyoncé say likes dress stage',
#  'september #number what career area beyonce start exploring',
#  "beyonce's first modelling event where",
#  "world's beautiful woman declared beyonce which national magazine",
#  'which month year gq feature beyonce cover',
#  'what tv network listed beyonce number #number #number sexiest artists list',
#  "who called beyonce world's beautiful woman",
#  'who called hottest female singer time',
#  'when appear cover gq',
#  'vh#number listed what number #number sexiest artists list',
#  'what year beyoncé first model tom ford',
#  "what magazine said beyoncé world's beautiful woman",
#  'what title complex award beyoncé',
#  'what museum made several models beyoncé wax',
#  "which parent beyonce's help co write book",
#  'which african american woman beyonce posed si swimsuit issue',
#  "what title beyonce's mother's book",
#  'when sports illustrated cover',
#  'who second african american cover',
#  'beyoncé second african american woman featured swimsuit cover magazine who first',
#  'what magazine said beyoncé best dressed celebrity',
#  'beyonce fan base referred what',
#  'bey hive fans beyonce called what',
#  'which social media company proclaimed beyonce fans know bey hive',
#  "what beyonce's fan base called",
#  'what fans used called',
#  'what latest term used describe beyoncé fans',
#  'what former word given beyoncé fans',
#  'what word bey hive derive',
#  'beyonce clothing line known what',
#  'which french magazine beyonce show cover',
#  'beyonce seen wearing what french magazine caused controversy',
#  'which year peta spark controversy beyonce',
#  'what peta criticize beyonce #number',
#  'what french magazine cover media criticize',
#  "how dressed cover l'officiel",
#  'what french magazine beyoncé appear wearing blackface tribal makeup',
#  'what clothing line beyoncé drew peta criticism',
#  "what type magazine l'officiel",
#  'which racial community gave criticism beyonce',
#  'which professor northeastern university wrote how race correlates criticisms beyonce',
#  "which company accused coloring beyonce's hair",
#  'what vogue request',
#  "how l'oreal respond accusations changing pictures",
#  'addition light skin color what else made part african american community criticize beyoncé',
#  '#number which music professor said believes criticism involve race well',
#  "who accused lightening beyoncé's skin advertisement",
#  "what advertisement beyoncé's skin supposedly lightened",
#  'who beyoncé tell #number use natural pictures rather retouched images',
#  'artist decade bestowed upon beyonce which magazine',
#  'whats first year beyonce appear time #number list',
#  'beyonce appeared time #number list what year',
#  'what guardian name',
#  'when beyonce first make time #number list',
#  'when time #number list cover',
#  'who said reigning national voice',
#  'who stated beyoncé important musician #numberst century',
#  'which publication named beyoncé artist decade',
#  'what list beyoncé make #number',
#  'who said beyoncé heir apparent diva united states',
#  'what year beyoncé featured time #number list well cover issue',
#  'which rock band cited beyonce third album',
#  'which friend learned beyonce preparing film country strong',
#  'nicky minaj became spokesperson which brand soda seeing beyonce involved',
#  'what influenced nicki minaj join pepsi global campaign',
#  'which band listed beyonce inspiration latest album',
#  'what beyonce influenced many entertainers',
#  'what film paltrow studying beyonce',
#  'which indie band said beyoncé inspiration one hteir albums',
#  "what name white rabbits' album",
#  "who studied beyoncé live concerts research film's music role",
#  'what name film gwyneth paltrow starred musician',
#  "beyoncé's pepsi commercial inspired which star join pepsi's global campaign #number",
#  'vh#number declared what song greatest song #numbers',
#  'how many grammy awards crazy love win',
#  'how many crazy love sell become one greatest selling singles history',
#  'what type organism named beyonce #number',
#  'place beyonce rock roll hall fame awarded when',
#  "which beyonce's songs called greatest song #numbers",
#  'how many grammy awards crazy love get',
#  'how many copies crazy love sell',
#  'who released single girls love beyonce',
#  'which publication considers crazy love one top #number songs time',
#  'who sang girls love beyoncé #number',
#  'what bryan lessard name beyoncé',
#  'how many copies albums beyonce sold us',
#  'totaling worldwide how many records beyonce sold',
#  'how many certifications beyonce awarded riaa',
#  "when beyonce destiny's child how many albums manage sell",
#  'who first female achieve international artist award american music awards',
#  'how many albums beyonce solo artist sold u',
#  'how many sold worldwide',
#  "how many records sold destiny's child",
#  'when receive legend award',
#  'how many music certifications received #numbers',
#  'how many records beyoncé sold united states',
#  'how many records beyoncé sold throughout world',
#  'who cited beyoncé top certified artist #numbers',
#  'how many certifications riaa give beyoncé',
#  'when beyoncé receive legend award',
#  "how many grammys beyonce total without destiny's child",
#  'who woman grammy awards beyonce',
#  'beyonce awarded how many grammy nominations',
#  'beyonce holds record how many wins one night female',
#  'how many awards broadcast film critics association awards #number beyonce bring home',
#  'how many grammies beyonce',
#  'how many grammy nominations beyonce',
#  'when set record grammy awards one night',
#  'who tied record grammies one night #number',
#  'how many grammys beyoncé',
#  'how many grammy nominations beyoncé',
#  'what beyoncé song song year #number',
#  'what movie beyoncé nominated best actress golden globe awards',
#  'which soda company beyonce partnered since #number',
#  'pepsi paid beyonce how much #number endorsement',
#  'which organization wrote letter beyonce pepsi endorsement deal',
#  "what percentage people positive beyonce's endorsement pepsi",
#  'when beyonce begin pepsi advetisments',
#  'who commercial beyonce #number',
#  'what agree #number million dollars #number',
#  'who sent letter asking reconsider pepsi deal',
#  'what soft drink company beyoncé worked since #number',
#  'how much beyoncé get deal soft drink company #number',
#  'who asked change mind soft drink deal due nature product',
#  'what organization discovered advertisements beyoncé soft drink company #number% positive',
#  'beyonce worked who perfumes true star true star gold',
#  "world's best selling celebrity perfume line belongs",
#  "beyonce's first fragrance what name",
#  'mrs carter show limited edition released what year',
#  'how much money mrs carter show limited edition fragrance make',
#  "what beyonce's #number perfume called",
#  'when second perfume heat rush released',
#  "what beyonce's third perfume named",
#  'how many editions heat launched',
#  'which emporio armani fragrance beyoncé promote #number',
#  'what year beyoncé introduce first fragrance',
#  "what beyoncé's first fragrance called",
#  'how many editions heat exist',
#  "how young beyonce when acquired deals american express l'oreal",
#  'what name video game cancelled beyonce',
#  'when beyonce begin deals name brands',
#  'how many people lost jobs when beyonce left video game deal',
#  'how suit settled',
#  'what name video game',
#  'what video game beyoncé back',
#  'what company producing video game',
#  'how many people lost jobs beyoncé backing deal',
#  'when disagreement settled court',
#  "who bayonce's management go business #number",
#  "agreement together beyonce's topshop new business called what",
#  'what type clothing parkwood topshop athletic ltd produce',
#  'company products set stores when',
#  'who beyonce partner london',
#  'when new line launch',
#  "what name beyoncé's management company",
#  'who beyoncé parkwood entertainment partner october #number',
#  'where topshop located',
#  'what new division topshop partnership',
#  'when discovered beyonce co owner music service tidal',
#  'parent company tidal became ownership #number',
#  'when announced beyonce co owner tidal',
#  'what kind service tidal',
#  'what criticism streaming services',
#  'what music streaming system beyoncé part owner',
#  'what parent company music service beyoncé owns part',
#  'who acquired parent company music service beyoncé owns part',
#  'what music service accused providing low royalty amounts',
#  "house dereon became known beyonce which beyonce's relatives",
#  "beyonce's grandma's name",
#  "beyonce's family's company name what",
#  "what types garments sold beyonce's clothing line",
#  "which two countries purchase beyonce's clothing line",
#  'who partnered beyonce start clothing line dereon',
#  'when beyonce mother start dereon',
#  "who business named beyonce's family",
#  'where items clothing line displayed',
#  'who shares house deréon fashion line introduction beyoncé',
#  'what name house deréon junior collection',
#  'what type accessory company beyonce partner #number',
#  '#number beyonce released dereon what country',
#  "back school shopping introduced what year beyonce's clothing line",
#  "what beyonce's fashion diva feature",
#  'what new idea beyonce mother launch #number',
#  'when beyonce partner c&a sell fashion brazil',
#  'what company beyoncé get together #number add shoes fashions',
#  'what name game put starwave mobile #number featured beyoncé fashions',
#  'what name junior fashions launched #number beyoncé mother',
#  'who beyoncé team #number get fashions brazil',
#  "sasha fierce deréon fashions sold stores included macy's what store",
#  'beyonce october #number partnered produce outdoor line clothing',
#  'beyonce topshops first products sold stores when',
#  'what new business called',
#  "what beyonce's percentage ownership new venture",
#  'when full line appear',
#  'what company beyoncé contract sell clothing england',
#  "what name equal partnership's fashion line beyoncé british company come #number",
#  'what type clothing british partnership beyoncé sell',
#  'what national disaster caused beyonce create survivor foundation',
#  'how much cash beyonce put venture survivor foundation startup',
#  'what hurricane years later katrina organization provide support',
#  'what beyonce rowland found #number',
#  'how much beyonce initially contribute foundation',
#  'how foundation changed recent years',
#  'what foundation beyoncé start hurricane katrina',
#  'how much money beyoncé contribute beginning hurricane katrina foundation',
#  "what hurricane beyoncé's foundation help",
#  'who beyonce participate hope haiti now: global benefit',
#  'beyonce opened cosmetology center what location',
#  "osama bin laden's death what single beyonce cover",
#  "how much shirt beyonce's image make",
#  'what enterprise beyonce mother start march #number #number',
#  'what charity benefited release song god bless usa',
#  'what participate george clooney',
#  'which two stars beyoncé help haiti earthquake organization',
#  'what beyoncé open brooklyn phoenix house #number',
#  'what lee greenwood song beyoncé cover osama bin laden killed',
#  'which national event caused beyonce produce demand plan',
#  'what song beyonce contribute campaign',
#  'beyonce contributing which food donation campaign',
#  'june #number #number where concert held chime change',
#  'beyonce speaking when said gift finding best qualities every human',
#  'demand plan video campaign followed what tragic event',
#  'what focus gucci chime change campaign',
#  'what crowdfunding platform used concert',
#  'what name campaign beyoncé others involved deals gun control',
#  'what school shooting prompted creation demand plan',
#  'what song beyoncé donate #number world humanitarian day campaign',
#  'who beyoncé work #number chime change campaign',
#  "what frédéric's nationalities",
#  'what era frédéric active',
#  'what instrument frédéric write primarily',
#  'what area frédéric born',
#  'what age frédéric depart poland',
#  'what year chopin born',
#  'what era chopin active',
#  'where chopin grow',
#  'what instrument mostly compose',
#  'what age chopin leave poland',
#  'when chopin die',
#  "what chopin's full name",
#  "majority chopin's compositions what instrument",
#  'chopin active what era',
#  'what year chopin born',
#  'what city chopin born raised',
#  'how old chopin when left poland',
#  'what era music chopin compose',
#  'what year chopin die',
#  'what age frédéric move paris',
#  'how many public performances frédéric estimated given remainder life',
#  'what year frédéric obtain citizenship france',
#  "what area frédéric's productive period composition taken place",
#  "what frédéric's likely cause death",
#  'where end living when #number',
#  'how many public shows perform last years life',
#  'what composer chopin develop friendship',
#  'what year gain citizenship france',
#  'what name woman relationship #number #number',
#  'what age chopin move paris',
#  'last #number years lived how many times chopin perform public',
#  'what year chopin become citizen france',
#  'last years life who person supported financially',
#  'what year chopin become french citizen',
#  'who gave chopin money last years life',
#  'what likely cause death chopin',
#  'what instrument every composition frédéric include',
#  'what concept frédéric credited creating',
#  'whose music frédéric admire thus provide influence work',
#  "what features marked frédéric's performance style made unique",
#  'what establishments frédéric frequently visit paris influenced career',
#  'which instrument every one compositions include',
#  'what concept chopin create',
#  "what two things chopin's performances known",
#  "what three composers influenced chopin's work",
#  'chopin wrote music lyrics what language lyrics',
#  "what instrument involved chopin's work",
#  'chopin composed several songs lyrics what language',
#  "chopin's performances known what",
#  'what three composers chopin take inspiration',
#  "what instrument chopin's compositions written",
#  'what language songs written chopin wrote music',
#  'what venue chopin often invited guest',
#  "what degree frédéric's association political insurrection",
#  "what parts frédéric's personal life influenced legacy leading symbol era",
#  'which era frédéric leave legacy leading symbol',
#  'what forms media frédéric subject',
#  'where chopin create majority compositions',
#  'chopin native what country',
#  'non direct association what',
#  'chopin closely associated what era',
#  'where chopin create works',
#  'chopin indirectly related what',
#  'chopin considered prominent symbol what',
#  'what village frédéric born',
#  'what date frédéric born',
#  'despite birthdate given parish baptismal what date given composer family instead',
#  "what latin form frédéric's full name",
#  'how many miles village frédéric born located west warsaw',
#  'where chopin born',
#  'who responsible creation duchy warsaw',
#  'when birthday recorded',
#  'what birth date considered actual birthday',
#  "chopin's given names latin what",
#  'duchy warsaw created',
#  "chopin's birth recorded when",
#  'what birth date considered correct chopin',
#  "what latin form chopin's name",
#  'chopin actually born outside warsaw what location',
#  'what famous french leader established polish state time',
#  "who frédéric's father marry #number",
#  'what date frédéric baptised',
#  "what language frédéric's father nicolas insist using household",
#  "what given name chopin's father",
#  "where chopin's father",
#  "chopin's father married who",
#  "what name chopin's godfather",
#  "what name chopin's eldest sister",
#  "what chopin's father's first name",
#  "where id chopin's father emigrate",
#  "what chopin's older sister's name",
#  'what month frédéric move warsaw family',
#  "what language frédéric's father teach moved warsaw",
#  'where frédéric live family warsaw',
#  "what two instruments frédéric's father play time",
#  'what frédéric prone early childhood result slight build',
#  "when chopin's family move warsaw",
#  "where chopin's father get teaching position",
#  "what instruments chopin's father play",
#  "what instrument chopin's mother teach",
#  'how old chopin when family moved warsaw',
#  "what language chopin's father teach",
#  "what two instruments chopin's father play",
#  "what instrument chopin's mother teach boarding house",
#  'where chopin live family warsaw',
#  "who frédéric's first professional teacher music",
#  'which sister frédéric play duets sometimes tutored time',
#  'what age frédéric start giving public concerts',
#  'what frédéric compose year #number',
#  'what earliest surviving musical notation composed frédéric',
#  "who chopin's initial piano teacher",
#  'which sisters chopin sometimes duet',
#  'what age chopin start playing publicly',
#  'what year chopin compose first work',
#  'what years chopin receive instruction żywny',
#  "what name chopin's first music teacher amateur musician",
#  "which chopin's sisters would play music",
#  'how old chopin when began perform public',
#  "who chopin's earliest piece music record dedicated",
#  'what year saxon palace taken russian governor use regarding military',
#  'what establishment today contains what known warsaw lyceum time',
#  "what building frédéric's new home adjacent",
#  "what palace frédéric sometimes invited companion ruler's son",
#  "what short poem spoke frédéric's popularity child",
#  'saxon palace taken military use what year',
#  'warsaw lyceum moved where',
#  'child chopin invited play son',
#  'what chopin create grand duke constantine',
#  'one works who affirmed popularity chopin child',
#  "what place chopin invited friend ruler's son",
#  'what title name ruler whose son chopin friends',
#  "what type musical piece chopin compose friend's ruling father",
#  'who wrote #number popularity chopin',
#  'what years frédéric visit warsaw lyceum lessons',
#  'who frédéric student involving music theory starting #number',
#  'what name mechanical organ frédéric performed #number',
#  'which tsar frédéric perform due success previous concerts',
#  "what date frédéric's first performance earned international esteem",
#  'who taught chopin play organ',
#  'chopin three years lessons',
#  'what instrument chopin play front tsar alexander',
#  'what gift tsar alexander give chopin',
#  "what first chopin's works gain international renown",
#  'who gave chopin instruction how play organ',
#  "what name teacher chopin's three year course began fall #number",
#  'what th ename mechanical organ chopin played #number',
#  'what tsar alexander give chopin',
#  'what title first commercially successful work',
#  'who frédéric guest visit szafarnia #number #number',
#  'which village frédéric first experience rural polish folk music',
#  'frédéric write letters stay szafarnia',
#  'what frédéric write parodies letters',
#  'vacation #number #number who chopin spend vacation',
#  'what type music chopin discover first time staying szafarnia',
#  'what name person who hosted chopin guest when discovered polish rural folk music',
#  'what title chopin gave spoof letters wrote',
#  'where chopin spend vacation #number #number',
#  "what year frédéric's youngest sister emilia pass away",
#  "what street frédéric's family move death youngest sister",
#  'what year frédéric leave warsaw moving family south annex krasiński palace',
#  "what chopin's family business become #numberth century",
#  'which artist created first known portrait frédéric',
#  "what year chopin's sister emilia die",
#  'what year chopin leave warsaw',
#  "what chopin family's business",
#  'what artist painted chopin family',
#  "who chopin's family died shortly moved #number",
#  'what year chopin leave warsaw',
#  'what chopin boarding house called english',
#  'what artist made portraits chopin family #number',
#  'chopin family boarding house male female students',
#  "individuals became intimate frédéric stay family apartments which two became part frédéric's social environment paris",
#  'which singer cited specifically someone frédéric attracted',
#  "what four boys family's boarding house became friends chopin",
#  'which singer chopin become fascinated',
#  "which chopin's works unknowingly dedicated gladkowska",
#  'when chopin receive last conservatory report',
#  "which two chopin's friends became part paris milieu",
#  'what name singing student chopin attracted',
#  'chopin reveal letters which parts work singing student infatuated',
#  'what musical piece larghetto dedicated female singing student chopin infatuated',
#  "how many boarders family's boarding house became intimate friends chopin",
#  'who frédéric visit berlin september #number',
#  'which opera director frédéric see works stay berlin',
#  'who frédéric guest stay berlin #number',
#  "what piece frédéric create specifically prince prince's daughter wanda",
#  'when chopin visit berlin',
#  'chopin go berlin',
#  'berlin saw operatic work who',
#  '#number trip back berlin chopin guest who',
#  'what piece chopin create prince antoni',
#  'what year chopin visit berlin still student',
#  'who chopin go berlin',
#  'what person who chopin went berlin work',
#  'who directed operas enjoyed berlin',
#  'what year chopin return berlin',
#  'what frédéric compose hearing niccolò paganini perform violin',
#  'what month frédéric make first appearance vienna',
#  'how many piano concerts frédéric perform vienna time',
#  'what date frédéric give first performance piano concerto #number f minor op #number',
#  'what chopin compose hearing niccolo paganini',
#  'where chopin debut completing studies',
#  'what piece chopin debut returning warsaw',
#  'when chopin return warsaw',
#  'critics say chopin delicate',
#  'who chopin hear play violin #number prompted write composisition',
#  'where chopin make debut completing education',
#  'how many public performances chopin where made debut completing education',
#  'how many weeks completing school chopin made public debut',
#  'what date frédéric begin journey western europe',
#  'which country frédéric go first setting western europe',
#  'what year companion woyciechowski depart poland enlist uprising warsaw',
#  "what historian commented events involving frédéric's friend poland contributed maturing",
#  'who said chopin set wide world clearly defined aim forever',
#  'who chopin leave austria',
#  'where chopin intend go austria',
#  'woyciechowski left chopin enlist what',
#  'what geographicla region opened chopin due composing performances',
#  'when chopin started take music world what last name person who went austria',
#  'what year uprising begin warsaw',
#  'what words chopin wrote friend when alone homesick',
#  'what year chopin learn uprising warsaw crushed',
#  'what event frédéric part when arrived paris later part september #number',
#  "what version frédéric's birth name begin using arriving france",
#  'what year frédéric officially acquire french citizenship',
#  'what two kinds relationships stated frédéric fellow poland natives exile',
#  'what nationality stated one frédéric felt identified',
#  'when chopin reach paris',
#  'going back poland chopin became part what',
#  'what year chopin become french citizen',
#  "what name chopin's biographer",
#  '#number what country chopin never return',
#  "what country's passport #number",
#  'what language chopin never completely ease speaking',
#  'what biographer chopin wrote chopin never considered french',
#  'due numbers expatriates poland uprising what become known',
#  'what city frédéric achieve celebrity status',
#  'who principal polish literary society frédéric became acquainted',
#  'what frédéric create verses poet adam mickiewicz',
#  'what poet chopin use verses songs',
#  'what people chopin meet paris',
#  'what name poet chopin became acquainted paris',
#  'what position poet who chopin knew paris hold',
#  'which friend frédéric failed achieve success england',
#  "who frédéric's trusted adviser paris",
#  'what familial role albert grzymała compared regards frédéric',
#  'who stated jack trades service frédéric',
#  ...]

# %%
# 首先先来看一下总词数
word_total = list()
for q in new_qlist:
    # 这里的q就是指的每一句话
    for w in q.split(' '):
        # w指的是每一个单词
        word_total.append(w)
        
word_total_unique = set(word_total)
# 输出总单词数
word_total.remove('')
print(len(word_total))
print(len(word_total_unique))
# Out:
# 562229
# 37731

# %%
# 统计一下qlist中出现1次，2次，3次... 出现的单词个数， 然后画一个plot. 这里的x轴是单词出现的次数（1，2，3，..)， y轴是单词个数

# step1:先统计词频
# dict_word_count:key：单词，value：词的出现次数
# 不用Counter的话，开始需要进行初始化
dict_word_count = {l:0 for l in word_total}
for value in word_total:
    dict_word_count[value] +=1

# step2：再根据词频统计出现1,2,3...n次的单词的个数
# 需要先把set保存，以此来作为字典的key
word_count_set = sorted(list(set(dict_word_count.values())))
dict_appear_count = {s:0 for s in word_count_set}
for w, v in dict_word_count.items():
    dict_appear_count[v] += 1

# %%
import matplotlib.pyplot as plt
# 绘制出现次数的图，x轴为出现的次数；y轴为出现次数的单词数量；
x_data = list(dict_appear_count.keys())
y_data = list(dict_appear_count.values())
fig = plt.figure()  #设置画布
ax1 = fig.add_subplot(111)
# 看前50个
k = 50
plt.plot(x_data[:k], y_data[:k])
ax1.set_xlabel(u'Word Appear Nums')
ax1.set_ylabel(u'Word Counts')
plt.show()

# 由此图可以看出词库中的一些单词经常使用，而绝大部分单词不常用

# %%
fig = plt.figure()  #设置画布
ax1 = fig.add_subplot(111)
ax1.hist(x_data, range=(0,2000),bins=30)
plt.show()

# %%
# 由频率图来对词表进行筛选,把出现次数少且多的词删去，大概为3
def removeLowFrequence(ori_list,vocabulary,thres = 3):
    #根据thres筛选词表，小于thres的词去掉
    new_list = []
    for q in ori_list:
        sentence = ' '.join([w for w in q.strip().split(' ') if vocabulary[w] >= thres])
        new_list.append(sentence)
    return new_list
new_qlist = removeLowFrequence(new_qlist, dict_word_count)

# %%
# 二. 文本的表示

# %%
# %%time
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()  # 定一个tf-idf的vectorizer
X_tfidf = vectorizer.fit_transform(new_qlist)   # 结果存放在X矩阵
# Out:
# Wall time: 713 ms

# %%
# %%time
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
def loadEmbedding(filename):
    #加载glove模型，转化为word2vec，再加载word2vec模型
    word2vec_temp_file = 'word2vec_temp.txt'
    glove2word2vec(filename,word2vec_temp_file)
    model = KeyedVectors.load_word2vec_format(word2vec_temp_file)
    return model

emb  =  loadEmbedding('glove.6B.200d.txt')# 这是 D*H的矩阵，这里的D是词典库的大小， H是词向量的大小。 
# 这需要从文本中读取来给定的每个单词的词向量
# 用average pooling的方法求算每个句子的句子向量
def computeGloveSentenceEach(sentence,embedding):
    #查找句子中每个词的embedding,将所有embedding进行加和求均值
    emb = np.zeros(200)
    # 将每个句子分成单独的词
    words = sentence.strip().split(' ')
    for w in words:
        if w not in embedding:
            #没有lookup的即为unknown
            w = 'unknown'
        emb += embedding[w]
    return emb / len(words)

def computeGloveSentence(qlist,embedding):
    #对每一个句子进行求均值的embedding
    X_w2v = np.zeros((len(qlist),200))
    for i, q in enumerate(qlist):
        # 这里的q是指的每一个句子
        X_w2v[i] = computeGloveSentenceEach(q,embedding)
    return X_w2v
    
X_w2v =   computeGloveSentence(new_qlist, emb)# 初始化完emb之后就可以对每一个句子来构建句子向量了，这个过程使用average pooling来实现
# Out:
# Wall time: 1min 16s

# %%
import heapq
from sklearn.metrics.pairwise import cosine_similarity

def get_least_numbers_big_data(alist, k):
    max_heap = []
    length = len(alist)
    if not alist or k <= 0 or k > length:
        return
    k-=1
    for ele in alist:
        if len(max_heap) <= k:
            heapq.heappush(max_heap, ele)
        else:
            heapq.heappushpop(max_heap, ele)
    return max_heap

# %%
def get_top_results_tfidf_noindex(query):
    # TODO 需要编写
    """
    给定用户输入的问题 query, 返回最有可能的TOP 5问题。这里面需要做到以下几点：
    1. 对于用户的输入 query 首先做一系列的预处理(上面提到的方法)，然后再转换成tf-idf向量（利用上面的vectorizer)
    2. 计算跟每个库里的问题之间的相似度
    3. 找出相似度最高的top5问题的答案
    """
    input_seq = query
    input_vec = vectorizer.transform([input_seq])
    result = list(cosine_similarity(input_vec, X_tfidf)[0])
    top_values = sorted(get_least_numbers_big_data(result, 5), reverse=True)

    top_idxs = []
    len_result = len(result)
    dict_visited = {}
    for value in top_values:
        for index in range(len_result):
            if value == result[index] and index not in dict_visited:
                top_idxs.append(index)
                dict_visited[index] = True

    top_idxs = top_idxs[:5]
    
    return [new_qlist[i] for i in top_idxs]  # 返回相似度最高的问题对应的答案，作为TOP5答案

# %%
line = 'hello world'
get_top_results_tfidf_noindex(line)
# Out:
# ['greek world joined what areas world',
#  'what largest world',
#  'what largest world',
#  'what largest world',
#  'what county world']

# %%
# 创建倒排表
'''
这里总结下：创建字典有两种方式--
1. 一种是开始就初始化，然后直接添加：；
2. 另一种是，开始只定义dict()，然后通过if判断是否在词典中，在的话+1，否则赋值；
'''
# Out:
# ['greek world joined what areas world',
#  'what largest world',
#  'what largest world',
#  'what largest world',
#  'what county world']
